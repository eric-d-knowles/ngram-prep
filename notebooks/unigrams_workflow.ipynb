# %% [markdown]
# # **Unigrams: Full Workflow**
# The primary purpose of the unigram workflow is to generate a vocabulary **whitelist** that can be used to filter out unwanted words from a multigram corpus. The workflow consists of two steps: (1) downloading the unigram corpus into a database and (2) filtering and normalizing the corpus and generating the whitelist.

# %% [markdown]
# ## **Setup**
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2

from stop_words import get_stop_words
from ngramprep.ngram_filter.config import FilterConfig
from ngramprep.ngram_filter.lemmatizer import CachedSpacyLemmatizer
from ngramprep.ngram_acquire import download_and_ingest_to_rocksdb
from ngramprep.ngram_filter.pipeline.orchestrator import build_processed_db
from ngramprep.utilities.peek import db_head, db_peek, db_peek_prefix

# %% [markdown]
# ### Configure
# Here we set basic parameters: the corpus to download, the size of the ngrams to download, and the size of the year bins.

# %%
db_path_stub = '/scratch/edk202/NLP_corpora/Google_Books/'
archive_path_stub = None
release = '20200217'
language = 'rus'
ngram_size = 1
bin_size = 10

# %% [markdown]
# ## **Step 1: Download and Ingest**

# %%
download_and_ingest_to_rocksdb(
    ngram_size=ngram_size,
    repo_release_id=release,
    repo_corpus_id=language,
    db_path_stub=db_path_stub,
    archive_path_stub=archive_path_stub,
    ngram_type="tagged",
    overwrite_db=True,
    open_type="write:packed24",
    compact_after_ingest=True
)
# Out:
# N-GRAM ACQUISITION PIPELINE
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Start Time: 2026-02-03 22:36:04
#
# Download Configuration
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Ngram repo:           https://books.storage.googleapis.com/?prefix=ngrams/books/20200217/rus/1-
# DB path:              /scratch/edk202/NLP_corpora/Google_Books/20200217/rus/1gram_files/1grams.db
# File range:           0 to 1
# Total files:          2
# Files to get:         2
# Skipping:             0
# Download workers:     2
# Batch size:           50,000
# Ngram size:           1
# Ngram type:           tagged
# Overwrite DB:         True
# DB Profile:           write:packed24
#
# Download Progress
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Files Processed: 100%|███████████████████████████████████████████████████████████| 2/2 [03:18<00:00]
# Post-Ingestion Compaction
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Compaction completed in 0:00:38
#
# Processing complete!
#
# Final Summary
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Fully processed files:       2
# Failed files:                0
# Total entries written:       6,862,543
# Write batches flushed:       2
# Uncompressed data processed: 7.05 GB
# Processing throughput:       30.46 MB/sec
#
# End Time: 2026-02-03 22:40:02.041942
# Total Runtime: 0:03:57.139840
# Time per file: 0:01:58.569920
# Files per hour: 30.4

# %% [markdown]
#  ## **Step 2: Filter, Normalize, and Generate Whitelist**
# `config.py` contains generic defaults for the filtering pipeline. You can override these defaults by passing option dictionaries to the `build_processed_db` function, as seen below. By default, we:
# 1. case-normalize the tokens
# 2. remove tokens containing non-alphanumeric text
# 3. remove stopwords using the `stop-words` package
# 4. lemmatize the tokens using the `spaCy` package—first using a lookup table and falling back to rules when lookups fail
# 5. Create a whitelist of the top 20,000 most frequent words that pass a `pyenchant` spell-check and appear in all corpora from 1900–2019 (inclusive).

# %%
filter_config = FilterConfig(
    stop_set=set(get_stop_words("russian")),
    lemma_gen=CachedSpacyLemmatizer(language="ru"),
    ascii_alpha_only=False,
    min_context_tokens=1,
    min_len=3,
    bin_size=bin_size
)

whitelist_options = {
    'output_whitelist_top_n': 30_000,
    'output_whitelist_year_range': (1900, 2019),
    'output_whitelist_spell_check': True,
    'output_whitelist_spell_check_language': "ru"
}

build_processed_db(
    filter_config=filter_config,
    mode="restart",
    ngram_size=ngram_size,
    repo_release_id=release,
    repo_corpus_id=language,
    db_path_stub=db_path_stub,
    num_workers=20,
    num_initial_work_units=300,
    cache_partitions=True,
    use_cached_partitions=False,
    progress_every_s=5,
    compact_after_ingest=True,
    **whitelist_options
);
# Out:
# N-GRAM FILTER PIPELINE
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Start Time: 2026-02-03 23:59:01
# Mode:       RESTART
#
# Configuration
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Source DB:            /scratch/edk202/NLP_corpora/Google_Books/20200217/rus/1gram_files/1grams.db
# Target DB:            ...dk202/NLP_corpora/Google_Books/20200217/rus/1gram_files/1grams_processed.db
# Temp directory:       ...tch/edk202/NLP_corpora/Google_Books/20200217/rus/1gram_files/processing_tmp
#
# Parallelism
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Workers:              20
# Initial work units:   300
#
# Database Profiles
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Reader profile:       read:packed24
# Writer profile:       write:packed24
#
# Ingestion Configuration
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Ingest readers:       8
# Queue size:           8
# Compact after ingest: True
#
# Worker Configuration
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Flush interval:       10.0s
#
# Temporal Binning
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Bin size:             10 (10-year bins)
#
# Filter Options
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Lowercase:            True
# Alpha only:           True
# ASCII alpha only:     False
# Min context tokens:   1
# Min token length:     3
# Stopword filtering:   enabled (421 stopwords)
# Lemmatization:        enabled
# Always include:       none
#
# Whitelist Configuration
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Input whitelist:      None
# Output whitelist:     ...ora/Google_Books/20200217/rus/1gram_files/1grams_processed.db/whitelist.txt
#   Top 30,000 tokens
#   Spell checking enabled (ru)
#   Year range: 1900-2019 (inclusive)
# Phase 1: Creating work units...
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Clean restart - creating new work units
# Sampling database to create 300 density-based work units...
# Created 300 balanced work units based on data density
# Cached partition results for future use
#
# Phase 2: Processing 300 work units with 20 workers...
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
#     items         kept%        workers        units          rate        elapsed
# ────────────────────────────────────────────────────────────────────────────────────
#    126.42K        42.0%         17/20       232·16·52       8.1k/s         16s
#     1.20M         81.7%         12/20       176·10·114     58.4k/s         21s
#     1.86M         81.8%         17/20       110·17·173     72.7k/s         26s
#     3.83M         86.2%         19/20       35·19·246      125.0k/s        31s
#     6.17M         88.9%          5/20        0·5·295       173.3k/s        36s
# ───────────────────────────────────── final ─────────────────────────────────────
#     6.86M         89.9%          0/20        0·0·300       171.9k/s        40s
#
# Phase 3: Ingesting 300 shards with 8 parallel readers...
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Shards Ingested: 100%|███████████████████████████████████████████████████████| 300/300 [05:53<00:00]
# Ingestion complete: 300 shards, 4,903,866 items in 353.2s (13,883 items/s)
#
# Phase 4: Finalizing database...
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
# Post-Ingestion Compaction
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Initial DB size:         1.22 GB
# Compaction completed in 0:00:07
# Size before:             1.22 GB
# Size after:              1.22 GB
# Space saved:             10.74 KB (0.0%)
#
# Phase 5: Generating output whitelist...
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#   Output path: ...LP_corpora/Google_Books/20200217/rus/1gram_files/1grams_processed.db/whitelist.txt
#   Extracting top 30,000 tokens
#   Spell checking enabled (ru)
#   Year range filter: 1900-2019 (inclusive)
# ---------------------------------------------------------------------------
# DictNotFoundError                         Traceback (most recent call last)
# File /scratch/edk202/lexichron/src/ngramprep/ngram_filter/pipeline/whitelist.py:115, in _create_spell_checker(language)
#     114 try:
# --> 115     return enchant.Dict(language)
#     116 except enchant.errors.DictNotFoundError as e:
#
# File /scratch/edk202/.conda/envs/lexichron/lib/python3.11/site-packages/enchant/__init__.py:553, in Dict.__init__(self, tag, broker)
#     552 # Now let the superclass initialise the C-library object
# --> 553 super().__init__()
#
# File /scratch/edk202/.conda/envs/lexichron/lib/python3.11/site-packages/enchant/__init__.py:149, in _EnchantObject.__init__(self)
#     148 if _e is not None:
# --> 149     self._init_this()
#
# File /scratch/edk202/.conda/envs/lexichron/lib/python3.11/site-packages/enchant/__init__.py:560, in Dict._init_this(self)
#     559 if self.tag:
# --> 560     this = self._broker._request_dict_data(self.tag)
#     561     self._switch_this(this, self._broker)
#
# File /scratch/edk202/.conda/envs/lexichron/lib/python3.11/site-packages/enchant/__init__.py:296, in Broker._request_dict_data(self, tag)
#     295     e_str += "Please check https://pyenchant.github.io/pyenchant/ for details"
# --> 296     self._raise_error(e_str % (tag,), DictNotFoundError)
#     297 if new_dict not in self._live_dicts:
#
# File /scratch/edk202/.conda/envs/lexichron/lib/python3.11/site-packages/enchant/__init__.py:242, in Broker._raise_error(self, default, eclass)
#     241 if err == "" or err is None:
# --> 242     raise eclass(default)
#     243 raise eclass(err.decode())
#
# DictNotFoundError: Dictionary for language 'ru' could not be found
# Please check https://pyenchant.github.io/pyenchant/ for details
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 17
#       1 filter_config = FilterConfig(
#       2     stop_set=set(get_stop_words("russian")),
#       3     lemma_gen=CachedSpacyLemmatizer(language="ru"),
#    (...)      7     bin_size=bin_size
#       8 )
#      10 whitelist_options = {
#      11     'output_whitelist_top_n': 30_000,
#      12     'output_whitelist_year_range': (1900, 2019),
#      13     'output_whitelist_spell_check': True,
#      14     'output_whitelist_spell_check_language': "ru"
#      15 }
# ---> 17 build_processed_db(
#      18     filter_config=filter_config,
#      19     mode="restart",
#      20     ngram_size=ngram_size,
#      21     repo_release_id=release,
#      22     repo_corpus_id=language,
#      23     db_path_stub=db_path_stub,
#      24     num_workers=20,
#      25     num_initial_work_units=300,
#      26     cache_partitions=True,
#      27     use_cached_partitions=False,
#      28     progress_every_s=5,
#      29     compact_after_ingest=True,
#      30     **whitelist_options
#      31 );
#
# File /scratch/edk202/lexichron/src/ngramprep/ngram_filter/pipeline/orchestrator.py:837, in build_processed_db(filter_config, pipeline_config, ngram_size, repo_release_id, repo_corpus_id, db_path_stub, stop_set, lemma_gen, min_len, whitelist_path, whitelist_min_count, whitelist_top_n, always_include, bin_size, min_context_tokens, num_workers, mode, use_smart_partitioning, num_initial_work_units, cache_partitions, use_cached_partitions, samples_per_worker, work_unit_claim_order, flush_interval_s, progress_every_s, ingest_num_readers, ingest_batch_items, ingest_queue_size, compact_after_ingest, output_whitelist_path, output_whitelist_top_n, output_whitelist_year_range, output_whitelist_spell_check, output_whitelist_spell_check_language)
#     835 # Run the pipeline
#     836 orchestrator = PipelineOrchestrator(constructed_pipeline_config, filter_config)
# --> 837 orchestrator.run()
#     839 return str(dst_db)
#
# File /scratch/edk202/lexichron/src/ngramprep/ngram_filter/pipeline/orchestrator.py:113, in PipelineOrchestrator.run(self)
#     111 self._compact_if_requested()
#     112 self._validate_final_result()
# --> 113 self._generate_output_whitelist()
#     114 self._print_completion_banner()
#
# File /scratch/edk202/lexichron/src/ngramprep/ngram_filter/pipeline/orchestrator.py:586, in PipelineOrchestrator._generate_output_whitelist(self)
#     583     print(f"  Year range filter: {start_year}-{end_year} (inclusive)")
#     585 start_time = time.perf_counter()
# --> 586 final_path = write_whitelist(
#     587     db_or_path=self.temp_paths['dst_db'],
#     588     dest=output_whitelist_path,
#     589     top=output_top_n,
#     590     decode=True,
#     591     sep="\t",
#     592     spell_check=spell_check,
#     593     spell_check_language=spell_check_language,
#     594     year_range=year_range,
#     595     bin_size=self.filter_config.bin_size,
#     596 )
#     597 elapsed = time.perf_counter() - start_time
#     599 # Count lines to report token count
#
# File /scratch/edk202/lexichron/src/ngramprep/ngram_filter/pipeline/whitelist.py:412, in write_whitelist(db_or_path, dest, top, decode, sep, spell_check, spell_check_language, year_range, bin_size)
#     383 def write_whitelist(
#     384         db_or_path: Union[str, Path, "rs.DB"],
#     385         dest: Union[str, Path],
#    (...)    393         bin_size: int = 1,
#     394 ) -> Path:
#     395     """
#     396     Write a plain TXT file of tokens ranked by total frequency (desc).
#     397     Each line: <token><sep><total_matches>
#    (...)    410         bin_size: Size of year bins (1 = annual data, 5 = 5-year bins, etc.)
#     411     """
# --> 412     return write_whitelist_streaming(
#     413         db_or_path, dest, top=top, decode=decode, sep=sep,
#     414         spell_check=spell_check, spell_check_language=spell_check_language,
#     415         year_range=year_range, bin_size=bin_size
#     416     )
#
# File /scratch/edk202/lexichron/src/ngramprep/ngram_filter/pipeline/whitelist.py:355, in write_whitelist_streaming(db_or_path, dest, top, decode, sep, spell_check, spell_check_language, year_range, bin_size)
#     352 with tmp.open("w", encoding="utf-8", newline="") as f:
#     353     if top is not None:
#     354         # Use optimized heap-based top-K for memory efficiency
# --> 355         items = _top_k_optimized(
#     356             db_or_path, top, decode=decode,
#     357             spell_check=spell_check,
#     358             spell_check_language=spell_check_language,
#     359             year_range=year_range,
#     360             bin_size=bin_size
#     361         )
#     362     else:
#     363         # Use streaming approach with Counter for better performance
#     364         items = _rank_all_counter(
#     365             db_or_path, decode=decode,
#     366             spell_check=spell_check,
#    (...)    369             bin_size=bin_size
#     370         )
#
# File /scratch/edk202/lexichron/src/ngramprep/ngram_filter/pipeline/whitelist.py:277, in _top_k_optimized(db_or_path, k, decode, spell_check, spell_check_language, year_range, bin_size)
#     274 if k <= 0:
#     275     return []
# --> 277 spell_checker = _create_spell_checker(spell_check_language) if spell_check else None
#     279 # Warn if spell checking was requested but is unavailable
#     280 if spell_check and spell_checker is None:
#
# File /scratch/edk202/lexichron/src/ngramprep/ngram_filter/pipeline/whitelist.py:117, in _create_spell_checker(language)
#     115     return enchant.Dict(language)
#     116 except enchant.errors.DictNotFoundError as e:
# --> 117     raise ValueError(
#     118         f"Spell checking language '{language}' not found. "
#     119         f"Install it with: enchant.broker.list_dicts() to see available languages."
#     120     ) from e
#     121 except Exception as e:
#     122     # For other enchant errors, raise with more context
#     123     raise ValueError(
#     124         f"Failed to create spell checker for language '{language}': {e}"
#     125     ) from e
#
# ValueError: Spell checking language 'ru' not found. Install it with: enchant.broker.list_dicts() to see available languages.

# %% [markdown]
# ## **Optional: Inspect Database Files**

# %% [markdown]
# ### `db_head`: Show first N records

# %%
db = f'{db_path_stub}{release}/{language}/{ngram_size}gram_files/{ngram_size}grams_processed.db'

db_head(db, n=5)
# Out:
# First 5 key-value pairs:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [ 1] Key:   FALSE
#      Value: Total: 124,503 occurrences in 110,465 volumes (1530-2010, 47 bins)
#
# [ 2] Key:   TRUE
#      Value: Total: 4,241,065 occurrences in 2,916,658 volumes (1500-2010, 50 bins)
#
# [ 3] Key:   aaa
#      Value: Total: 4,449,225 occurrences in 1,052,377 volumes (1470-2010, 49 bins)
#
# [ 4] Key:   aaaa
#      Value: Total: 472,912 occurrences in 91,764 volumes (1470-2010, 43 bins)
#
# [ 5] Key:   aaaaa
#      Value: Total: 54,371 occurrences in 22,966 volumes (1580-2010, 42 bins)

# %% [markdown]
# ### `db_peek`: Show records starting from a key

# %%
db = f'{db_path_stub}{release}/{language}/{ngram_size}gram_files/{ngram_size}grams_processed.db'

db_peek(db, start_key="à", n=5)
# Out:
# 5 key-value pairs starting from c3a0:
# ────────────────────────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ### `db_peek_prefix`: Show records matching a prefix

# %%
db = f'{db_path_stub}{release}/{language}/{ngram_size}gram_files/{ngram_size}grams_processed.db'

db_peek_prefix(db, prefix=b"tarnation", n=5)
# Out:
# 5 key-value pairs with prefix 7461726e6174696f6e:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [ 1] Key:   tarnation
#      Value: Total: 67,827 occurrences in 48,385 volumes (1630-2010, 35 bins)
#
# [ 2] Key:   tarnational
#      Value: Total: 114 occurrences in 92 volumes (1910-2010, 11 bins)
#
# [ 3] Key:   tarnationest
#      Value: Total: 53 occurrences in 53 volumes (1840-2010, 15 bins)
#
# [ 4] Key:   tarnationly
#      Value: Total: 94 occurrences in 94 volumes (1830-2010, 16 bins)
#
# [ 5] Key:   tarnations
#      Value: Total: 1,189 occurrences in 1,048 volumes (1600-2010, 29 bins)
