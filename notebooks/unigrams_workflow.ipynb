# %% [markdown]
# # **Unigrams: Full Workflow**
# The primary purpose of the unigram workflow is to generate a vocabulary **whitelist** that can be used to filter out unwanted words from a multigram corpus. The workflow consists of two steps: (1) downloading the unigram corpus into a database and (2) filtering and normalizing the corpus and generating the whitelist.

# %% [markdown]
# ## **Setup**
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2

from ngramprep.ngram_filter import FilterConfig, PipelineConfig, load_stopwords
from ngramprep.ngram_filter.lemmatizer import CachedSpacyLemmatizer
from ngramprep.ngram_acquire import download_and_ingest_to_rocksdb
from ngramprep.ngram_filter.pipeline.orchestrator import build_processed_db
from ngramprep.utilities.peek import db_head, db_peek, db_peek_prefix
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Configure
# Here we set basic parameters: the corpus to download, the size of the ngrams to download, and the size of the year bins.

# %%
db_path_stub = '/scratch/edk202/NLP_corpora/Google_Books/'
archive_path_stub = None
release = '20200217'
language = 'rus'
ngram_size = 1
bin_size = 10

# %% [markdown]
# ## **Step 1: Download and Ingest**

# %%
download_and_ingest_to_rocksdb(
    ngram_size=ngram_size,
    repo_release_id=release,
    repo_corpus_id=language,
    db_path_stub=db_path_stub,
    archive_path_stub=archive_path_stub,
    ngram_type="tagged",
    overwrite_db=True,
    open_type="write:packed24",
    compact_after_ingest=True
)
# Out:
# N-GRAM ACQUISITION PIPELINE
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Start Time: 2026-02-04 20:18:53
#
# Download Configuration
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Ngram repo:           https://books.storage.googleapis.com/?prefix=ngrams/books/20200217/rus/1-
# DB path:              /scratch/edk202/NLP_corpora/Google_Books/20200217/rus/1gram_files/1grams.db
# File range:           0 to 1
# Total files:          2
# Files to get:         2
# Skipping:             0
# Download workers:     2
# Batch size:           50,000
# Ngram size:           1
# Ngram type:           tagged
# Overwrite DB:         True
# DB Profile:           write:packed24
#
# Download Progress
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Files Processed: 100%|███████████████████████████████████████████████████████████| 2/2 [04:22<00:00]
# Post-Ingestion Compaction
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Compaction completed in 0:00:43
#
# Processing complete!
#
# Final Summary
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Fully processed files:       2
# Failed files:                0
# Total entries written:       6,862,543
# Write batches flushed:       2
# Uncompressed data processed: 7.05 GB
# Processing throughput:       23.50 MB/sec
#
# End Time: 2026-02-04 20:24:00.755777
# Total Runtime: 0:05:07.344078
# Time per file: 0:02:33.672039
# Files per hour: 23.4

# %% [markdown]
#  ## **Step 2: Filter, Normalize, and Generate Whitelist**
# `config.py` contains generic defaults for the filtering pipeline. You can override these defaults by passing option dictionaries to the `build_processed_db` function, as seen below. By default, we:
# 1. case-normalize the tokens
# 2. remove tokens containing non-alphanumeric text
# 3. remove stopwords using the `stop-words` package
# 4. lemmatize the tokens using the `spaCy` package—first using a lookup table and falling back to rules when lookups fail
# 5. Create a whitelist of the top 20,000 most frequent words that pass a `pyenchant` spell-check and appear in all corpora from 1900–2019 (inclusive).

# %%
stop_set, stop_lang = load_stopwords("ru")

filter_config = FilterConfig(
    stop_set=stop_set,
    stop_words_language=stop_lang,
    lemma_gen=CachedSpacyLemmatizer(language="ru"),
    ascii_alpha_only=False,
    min_context_tokens=1,
    min_len=3,
    bin_size=bin_size
)

pipeline_config = PipelineConfig(
    # Path construction
    ngram_size=ngram_size,
    repo_release_id=release,
    repo_corpus_id=language,
    db_path_stub=db_path_stub,
    # Pipeline options
    mode="restart",
    num_workers=20,
    num_initial_work_units=300,
    cache_partitions=True,
    use_cached_partitions=False,
    progress_every_s=5,
    compact_after_ingest=True,
    # Output whitelist options
    output_whitelist_path="default",
    output_whitelist_top_n=30_000,
    output_whitelist_year_range=(1900, 2019),
    output_whitelist_spell_check=True,
    output_whitelist_spell_check_language="ru_RU"
)

build_processed_db(
    filter_config=filter_config,
    pipeline_config=pipeline_config
);
# Out:
# N-GRAM FILTER PIPELINE
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Start Time: 2026-02-04 21:13:04
# Mode:       RESTART
#
# Configuration
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Source DB:            /scratch/edk202/NLP_corpora/Google_Books/20200217/rus/1gram_files/1grams.db
# Target DB:            ...dk202/NLP_corpora/Google_Books/20200217/rus/1gram_files/1grams_processed.db
# Temp directory:       ...tch/edk202/NLP_corpora/Google_Books/20200217/rus/1gram_files/processing_tmp
#
# Parallelism
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Workers:              20
# Initial work units:   300
#
# Database Profiles
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Reader profile:       read:packed24
# Writer profile:       write:packed24
#
# Ingestion Configuration
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Ingest readers:       8
# Queue size:           8
# Compact after ingest: True
#
# Worker Configuration
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Flush interval:       10.0s
#
# Temporal Binning
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Bin size:             10 (10-year bins)
#
# Filter Options
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Lowercase:            True
# Alpha only:           True
# ASCII alpha only:     False
# Min context tokens:   1
# Min token length:     3
# Stopword filtering:   enabled (421 stopwords [ru])
# Lemmatization:        enabled
# Always include:       none
#
# Whitelist Configuration
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Input whitelist:      None
# Output whitelist:     ...ora/Google_Books/20200217/rus/1gram_files/1grams_processed.db/whitelist.txt
#   Top 30,000 tokens
#   Spell checking enabled (ru_RU)
#   Year range: 1900-2019 (inclusive)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[15], line 35
#       3 filter_config = FilterConfig(
#       4     stop_set=stop_set,
#       5     stop_words_language=stop_lang,
#    (...)     10     bin_size=bin_size
#      11 )
#      13 pipeline_config = PipelineConfig(
#      14     # Path construction
#      15     ngram_size=ngram_size,
#    (...)     32     output_whitelist_spell_check_language="ru_RU"
#      33 )
# ---> 35 build_processed_db(
#      36     filter_config=filter_config,
#      37     pipeline_config=pipeline_config
#      38 );
#
# File /scratch/edk202/lexichron/src/ngramprep/ngram_filter/pipeline/orchestrator.py:70, in build_processed_db(filter_config, pipeline_config, ngram_size, repo_release_id, repo_corpus_id, db_path_stub, stop_set, lemma_gen, min_len, whitelist_path, whitelist_min_count, whitelist_top_n, always_include, bin_size, min_context_tokens, num_workers, mode, use_smart_partitioning, num_initial_work_units, cache_partitions, use_cached_partitions, samples_per_worker, work_unit_claim_order, flush_interval_s, progress_every_s, ingest_num_readers, ingest_batch_items, ingest_queue_size, compact_after_ingest, output_whitelist_path, output_whitelist_top_n, output_whitelist_year_range, output_whitelist_spell_check, output_whitelist_spell_check_language)
#      63 def __init__(
#      64     self,
#      65     pipeline_config: PipelineConfig,
#      66     filter_config: FilterConfig,
#      67 ):
#      68     """
#      69     Initialize pipeline orchestrator.
# ---> 70
#      71     Args:
#      72         pipeline_config: Configuration for pipeline execution
#      73         filter_config: Configuration for ngram filtering
#      74     """
#      75     self.pipeline_config = pipeline_config
#      76     self.filter_config = filter_config
#
# File /scratch/edk202/lexichron/src/ngramprep/ngram_filter/pipeline/orchestrator.py:104, in PipelineOrchestrator.run(self)
#      96 print_pipeline_header(
#      97     self.pipeline_config,
#      98     self.filter_config,
#      99     worker_config,
#     100     self.temp_paths,
#     101 )
#     103 # Prepare all resources using setup module
# --> 104 self.temp_paths, self.filter_config = self.setup.prepare_all()
#     106 # Execute pipeline phases
#     107 self._create_work_units()
#
# File /scratch/edk202/lexichron/src/ngramprep/ngram_filter/pipeline/setup.py:49, in PipelineSetup.prepare_all(self)
#      42 def prepare_all(self) -> tuple[dict[str, Path], FilterConfig]:
#      43     """
#      44     Prepare all resources for pipeline execution.
#      45
#      46     Returns:
#      47         Tuple of (paths dictionary, updated filter config)
#      48     """
# ---> 49     prepare_directories(self.temp_paths, self.pipeline_config)
#      50     self.filter_config = prepare_vocabulary_index(self.filter_config)
#      51     self.filter_config = prepare_whitelist(self.filter_config)
#
# File /scratch/edk202/lexichron/src/ngramprep/ngram_filter/pipeline/setup.py:108, in prepare_directories(temp_paths, pipeline_config)
#     106 # Clean temp directory only for restart mode (reprocess preserves cache)
#     107 if mode == 'restart' and temp_paths['tmp_dir'].exists():
# --> 108     shutil.rmtree(temp_paths['tmp_dir'])
#     110 # Create temp directories
#     111 temp_paths['tmp_dir'].mkdir(parents=True, exist_ok=True)
#
# File /scratch/edk202/.conda/envs/lexichron/lib/python3.11/shutil.py:763, in rmtree(path, ignore_errors, onerror, dir_fd)
#     761         os.rmdir(path, dir_fd=dir_fd)
#     762     except OSError:
# --> 763         onerror(os.rmdir, path, sys.exc_info())
#     764 else:
#     765     try:
#     766         # symlinks to directories are forbidden, see bug #1669
#
# File /scratch/edk202/.conda/envs/lexichron/lib/python3.11/shutil.py:761, in rmtree(path, ignore_errors, onerror, dir_fd)
#     759 fd_closed = True
#     760 try:
# --> 761     os.rmdir(path, dir_fd=dir_fd)
#     762 except OSError:
#     763     onerror(os.rmdir, path, sys.exc_info())
#
# OSError: [Errno 39] Directory not empty: '/scratch/edk202/NLP_corpora/Google_Books/20200217/rus/1gram_files/processing_tmp'

# %% [markdown]
# ## **Optional: Inspect Database Files**

# %% [markdown]
# ### `db_head`: Show first N records

# %%
db = f'{db_path_stub}{release}/{language}/{ngram_size}gram_files/{ngram_size}grams_processed.db'

db_head(db, n=5)
# Out:
# First 5 key-value pairs:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [ 1] Key:   aaa
#      Value: Total: 2,201 occurrences in 1,190 volumes (1830-2010, 17 bins)
#
# [ 2] Key:   aaaa
#      Value: Total: 453 occurrences in 320 volumes (1760-2010, 11 bins)
#
# [ 3] Key:   aaaaa
#      Value: Total: 426 occurrences in 111 volumes (1920-2010, 9 bins)
#
# [ 4] Key:   aaas
#      Value: Total: 112 occurrences in 72 volumes (1960-2010, 6 bins)
#
# [ 5] Key:   aab
#      Value: Total: 130 occurrences in 106 volumes (1910-2010, 11 bins)

# %% [markdown]
# ### `db_peek`: Show records starting from a key

# %%
db = f'{db_path_stub}{release}/{language}/{ngram_size}gram_files/{ngram_size}grams_processed.db'

db_peek(db, start_key="люди", n=5)
# Out:
# 5 key-value pairs starting from d0bbd18ed0b4d0b8:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [ 1] Key:   людибратья
#      Value: Total: 80 occurrences in 57 volumes (1890-2010, 11 bins)
#
# [ 2] Key:   людиг
#      Value: Total: 70 occurrences in 70 volumes (1910-2010, 11 bins)
#
# [ 3] Key:   людие
#      Value: Total: 25,898 occurrences in 12,302 volumes (1690-2010, 22 bins)
#
# [ 4] Key:   людией
#      Value: Total: 85 occurrences in 84 volumes (1920-2010, 10 bins)
#
# [ 5] Key:   людизвери
#      Value: Total: 70 occurrences in 69 volumes (1920-2010, 10 bins)

# %% [markdown]
# ### `db_peek_prefix`: Show records matching a prefix

# %%
db = f'{db_path_stub}{release}/{language}/{ngram_size}gram_files/{ngram_size}grams_processed.db'

db_peek_prefix(db, prefix="правительство", n=5)
# Out:
# 5 key-value pairs with prefix d0bfd180d0b0d0b2d0b8d182d0b5d0bbd18cd181d182d0b2d0be:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [ 1] Key:   правительство
#      Value: Total: 18,778,104 occurrences in 1,742,455 volumes (1510-2010, 34 bins)
#
# [ 2] Key:   правительствов
#      Value: Total: 121 occurrences in 118 volumes (1910-2010, 11 bins)
#
# [ 3] Key:   правительствовал
#      Value: Total: 142 occurrences in 118 volumes (1810-2010, 11 bins)
#
# [ 4] Key:   правительствовала
#      Value: Total: 96 occurrences in 96 volumes (1750-2010, 16 bins)
#
# [ 5] Key:   правительствовали
#      Value: Total: 140 occurrences in 130 volumes (1840-2010, 14 bins)
