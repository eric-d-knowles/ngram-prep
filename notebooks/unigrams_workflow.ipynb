# %% [markdown]
# # **Unigrams: Full Workflow**
# The primary purpose of the unigram workflow is to generate a vocabulary **whitelist** that can be used to filter out unwanted words from a multigram corpus. The workflow consists of two steps: (1) downloading the unigram corpus into a database and (2) filtering and normalizing the corpus and generating the whitelist.

# %% [markdown]
# ## **Setup**
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2

from ngramprep.ngram_filter import FilterConfig, PipelineConfig, load_stopwords
from ngramprep.ngram_filter.lemmatizer import CachedSpacyLemmatizer
from ngramprep.ngram_acquire import download_and_ingest_to_rocksdb
from ngramprep.ngram_filter.pipeline.orchestrator import build_processed_db
from ngramprep.utilities.peek import db_head, db_peek, db_peek_prefix
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
#
# ModuleNotFoundError                       Traceback (most recent call last)
#
# Cell In[1], line 4
#
#       1 get_ipython().run_line_magic('load_ext', 'autoreload')
#
#       2 get_ipython().run_line_magic('autoreload', '2')
#
# ----> 4 from ngramprep.ngram_filter import FilterConfig, PipelineConfig, load_stopwords
#
#       5 from ngramprep.ngram_filter.lemmatizer import CachedSpacyLemmatizer
#
#       6 from ngramprep.ngram_acquire import download_and_ingest_to_rocksdb
#
#
#
# ModuleNotFoundError: No module named 'ngramprep'

# %% [markdown]
# ### Configure
# Here we set basic parameters: the corpus to download, the size of the ngrams to download, and the size of the year bins.

# %%
db_path_stub = '/scratch/edk202/NLP_corpora/Google_Books/'
archive_path_stub = None
release = '20200217'
language = 'eng'
ngram_size = 1
bin_size = 2

# %% [markdown]
# ## **Step 1: Download and Ingest**

# %%
download_and_ingest_to_rocksdb(
    ngram_size=ngram_size,
    repo_release_id=release,
    repo_corpus_id=language,
    db_path_stub=db_path_stub,
    archive_path_stub=archive_path_stub,
    ngram_type="tagged",
    overwrite_db=True,
    open_type="write:packed24",
    compact_after_ingest=True
)
# Out:
# N-GRAM ACQUISITION PIPELINE
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Start Time: 2026-03-07 11:33:54
#
# Download Configuration
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Ngram repo:           ...//books.storage.googleapis.com/?prefix=ngrams/books/20200217/eng-fiction/1-
# DB path:              .../edk202/NLP_corpora/Google_Books/20200217/eng-fiction/1gram_files/1grams.db
# File range:           0 to 0
# Total files:          1
# Files to get:         1
# Skipping:             0
# Download workers:     1
# Batch size:           50,000
# Ngram size:           1
# Ngram type:           tagged
# Overwrite DB:         True
# DB Profile:           write:packed24
#
# Download Progress
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Files Processed: 100%|███████████████████████████████████████████████████████████| 1/1 [02:07<00:00]
# Post-Ingestion Compaction
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Compaction completed in 0:00:18
#
# Processing complete!
#
# Final Summary
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Fully processed files:       1
# Failed files:                0
# Total entries written:       2,489,457
# Write batches flushed:       1
# Uncompressed data processed: 2.78 GB
# Processing throughput:       19.37 MB/sec
#
# End Time: 2026-03-07 11:36:21.810919
# Total Runtime: 0:02:26.834181
# Time per file: 0:02:26.834181
# Files per hour: 24.5

# %% [markdown]
#  ## **Step 2: Filter, Normalize, and Generate Whitelist**
# `config.py` contains generic defaults for the filtering pipeline. You can override these defaults by passing option dictionaries to the `build_processed_db` function, as seen below. By default, we:
# 1. case-normalize the tokens
# 2. remove tokens containing non-alphanumeric text
# 3. remove stopwords using the `stop-words` package
# 4. lemmatize the tokens using the `spaCy` package—first using a lookup table and falling back to rules when lookups fail
# 5. Create a whitelist of the top 30,000 most frequent words that pass a `pyenchant` spell-check and appear in all corpora from 1968–2019 (inclusive).

# %%
stop_set, stop_lang = load_stopwords("en")

filter_config = FilterConfig(
    stop_set=stop_set,
    stop_words_language=stop_lang,
    lemma_gen=CachedSpacyLemmatizer(language="en"),
    ascii_alpha_only=True,
    min_context_tokens=1,
    min_len=3,
    bin_size=bin_size
)

pipeline_config = PipelineConfig(
    # Path construction
    ngram_size=ngram_size,
    repo_release_id=release,
    repo_corpus_id=language,
    db_path_stub=db_path_stub,
    # Pipeline options
    mode="restart",
    num_workers=20,
    num_initial_work_units=300,
    cache_partitions=True,
    use_cached_partitions=False,
    progress_every_s=5,
    compact_after_ingest=True,
    # Output whitelist options
    output_whitelist_path="default",
    output_whitelist_top_n=30_000,
    output_whitelist_year_range=(1968, 2019),
    output_whitelist_spell_check=True,
    output_whitelist_spell_check_language="en_EN"
)

build_processed_db(
    filter_config=filter_config,
    pipeline_config=pipeline_config
);
# Out:
# N-GRAM FILTER PIPELINE
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Start Time: 2026-03-07 11:36:22
# Mode:       RESTART
#
# Configuration
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Source DB:            .../edk202/NLP_corpora/Google_Books/20200217/eng-fiction/1gram_files/1grams.db
# Target DB:            ...P_corpora/Google_Books/20200217/eng-fiction/1gram_files/1grams_processed.db
# Temp directory:       ...02/NLP_corpora/Google_Books/20200217/eng-fiction/1gram_files/processing_tmp
#
# Parallelism
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Workers:              20
# Initial work units:   300
#
# Database Profiles
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Reader profile:       read:packed24
# Writer profile:       write:packed24
#
# Ingestion Configuration
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Ingest readers:       8
# Queue size:           8
# Compact after ingest: True
#
# Worker Configuration
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Flush interval:       10.0s
#
# Temporal Binning
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Bin size:             2 (2-year bins)
#
# Filter Options
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Lowercase:            True
# Alpha only:           True
# ASCII alpha only:     True
# Min context tokens:   1
# Min token length:     3
# Stopword filtering:   enabled (174 stopwords [en])
# Lemmatization:        enabled
# Always include:       none
#
# Whitelist Configuration
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Input whitelist:      None
# Output whitelist:     ...le_Books/20200217/eng-fiction/1gram_files/1grams_processed.db/whitelist.txt
#   Top 30,000 tokens
#   Spell checking enabled (en_EN)
#   Year range: 1968-2019 (inclusive)
#
#
# Phase 1: Creating work units...
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Clean restart - creating new work units
# Sampling database to create 300 density-based work units...
# Created 300 balanced work units based on data density
# Cached partition results for future use
#
# Phase 2: Processing 300 work units with 20 workers...
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
#     items         kept%        workers        units          rate        elapsed
# ────────────────────────────────────────────────────────────────────────────────────
#    621.62K        81.1%         14/20       212·15·73      35.4k/s         18s
#     1.02M         81.3%         10/20       167·11·122     45.1k/s         23s
#     1.47M         83.5%         13/20       113·14·173     53.2k/s         28s
#     1.96M         83.4%         11/20       59·10·231      60.0k/s         33s
#     2.46M         83.3%          8/20        0·8·292       65.3k/s         38s
# ───────────────────────────────────── final ─────────────────────────────────────
#     2.49M         83.4%          0/20        0·0·300       63.6k/s         39s
#
# Phase 3: Ingesting 300 shards with 8 parallel readers...
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Shards Ingested: 100%|███████████████████████████████████████████████████████| 300/300 [05:54<00:00]
# Ingestion complete: 300 shards, 1,456,589 items in 354.3s (4,111 items/s)
#
# Phase 4: Finalizing database...
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#
# Post-Ingestion Compaction
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Initial DB size:         1.13 GB
# Compaction completed in 0:00:06
# Size before:             1.13 GB
# Size after:              1.13 GB
# Space saved:             8.22 KB (0.0%)
#
# Phase 5: Generating output whitelist...
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#   Output path: ...ra/Google_Books/20200217/eng-fiction/1gram_files/1grams_processed.db/whitelist.txt
#   Extracting top 30,000 tokens
#   Spell checking enabled (en_EN)
#   Year range filter: 1968-2019 (inclusive)
#   Generated whitelist with 30,000 tokens in 12.0s
#
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ PROCESSING COMPLETE                                                                              │
# ├──────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ Items: 1,119,917 (estimated)                                                                     │
# │ Size: 1.13 GB                                                                                    │
# │ Database: ...202/NLP_corpora/Google_Books/20200217/eng-fiction/1gram_files/1grams_processed.db   │
# │ Whitelist: .../Google_Books/20200217/eng-fiction/1gram_files/1grams_processed.db/whitelist.txt   │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ## **Optional: Inspect Database Files**
# ### `db_head`: Show first N records

# %%
db = f'{db_path_stub}{release}/{language}/{ngram_size}gram_files/{ngram_size}grams_processed.db'

db_head(db, n=5)
# Out:
# First 5 key-value pairs:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [ 1] Key:   FALSE
#      Value: Total: 16,185 occurrences in 14,116 volumes (1684-2018, 128 bins)
#
# [ 2] Key:   TRUE
#      Value: Total: 429,584 occurrences in 319,392 volumes (1586-2018, 158 bins)
#
# [ 3] Key:   aaa
#      Value: Total: 51,097 occurrences in 29,079 volumes (1684-2018, 113 bins)
#
# [ 4] Key:   aaaa
#      Value: Total: 5,845 occurrences in 4,093 volumes (1802-2018, 82 bins)
#
# [ 5] Key:   aaaaa
#      Value: Total: 4,466 occurrences in 2,432 volumes (1818-2018, 62 bins)

# %% [markdown]
# ### `db_peek`: Show records starting from a key

# %%
db = f'{db_path_stub}{release}/{language}/{ngram_size}gram_files/{ngram_size}grams_processed.db'

db_peek(db, start_key="horse", n=5)
# Out:
# 5 key-value pairs starting from 686f727365:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [ 1] Key:   horse
#      Value: Total: 33,039,696 occurrences in 2,525,705 volumes (1586-2018, 183 bins)
#
# [ 2] Key:   horsea
#      Value: Total: 507 occurrences in 270 volumes (1770-2018, 79 bins)
#
# [ 3] Key:   horseack
#      Value: Total: 42 occurrences in 41 volumes (1824-2014, 30 bins)
#
# [ 4] Key:   horseand
#      Value: Total: 791 occurrences in 748 volumes (1800-2018, 73 bins)
#
# [ 5] Key:   horseapple
#      Value: Total: 84 occurrences in 57 volumes (1940-2018, 19 bins)

# %% [markdown]
# ### `db_peek_prefix`: Show records matching a prefix

# %%
db = f'{db_path_stub}{release}/{language}/{ngram_size}gram_files/{ngram_size}grams_processed.db'

db_peek_prefix(db, prefix="pony", n=5)
# Out:
# 5 key-value pairs with prefix 706f6e79:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [ 1] Key:   pony
#      Value: Total: 2,157,227 occurrences in 516,236 volumes (1586-2018, 117 bins)
#
# [ 2] Key:   ponyard
#      Value: Total: 144 occurrences in 104 volumes (1730-2018, 35 bins)
#
# [ 3] Key:   ponyback
#      Value: Total: 273 occurrences in 225 volumes (1842-2018, 52 bins)
#
# [ 4] Key:   ponyboy
#      Value: Total: 4,926 occurrences in 494 volumes (1884-2018, 29 bins)
#
# [ 5] Key:   ponycarriage
#      Value: Total: 1,338 occurrences in 1,130 volumes (1826-2018, 85 bins)
